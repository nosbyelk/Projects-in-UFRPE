# %% [markdown]
# <a href="https://colab.research.google.com/github/nosbyelk/exponential_smoothing/blob/main/Quem_pode_imaginar_o_capital_fict%C3%ADcio_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import nltk
import os
import pandas
from nltk.corpus import stopwords
from wordcloud import WordCloud
from matplotlib import pyplot as plt
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd
import io

df = pd.read_csv('iFood.csv', sep='|', encoding='latin-1', error_bad_lines=False)
df
# Out:
#                                                 tuites
# 0    passei altos dias la em Recife e o ifood n col...
# 1    Eu tô ouvindo cada história do iFood.. só essa...
# 2    Queria muito estar em Caruaru ou Recife (e não...
# 3    Queria donuts e recife não tem um lugar perto ...
# 4    Recife se acabando em chuva e o ifood faz oq? ...
# ..                                                 ...
# 269  as comidas do ifood daqui eh mais cara que em ...
# 270  Não aguento mais, receber tanta coisa do iFood...
# 271  Galera os motoqueiros dos deliverys ifood rapp...
# 272  Ações do iFood disparadas, ngm saiu de casa em...
# 273  Vou até olhar no ifood quanto está o da Atlânt...
#
# [274 rows x 1 columns]

# %%
df.describe()
# Out:
#                                                    tuites
# count                                                 274
# unique                                                273
# top     (pelo menos em recife) os horários de previsão...
# freq                                                    2

# %%
df['length'] = df['tuites'].apply(len)
df.head()
# Out:
#                                               tuites  length
# 0  passei altos dias la em Recife e o ifood n col...      73
# 1  Eu tô ouvindo cada história do iFood.. só essa...     192
# 2  Queria muito estar em Caruaru ou Recife (e não...     102
# 3  Queria donuts e recife não tem um lugar perto ...      90
# 4  Recife se acabando em chuva e o ifood faz oq? ...      88

# %%
df.length.describe()
# Out:
# count    274.000000
# mean     138.726277
# std       74.974781
# min       26.000000
# 25%       80.000000
# 50%      117.500000
# 75%      197.750000
# max      348.000000
# Name: length, dtype: float64

# %%
df[df['length'] == 159]['tuites'].iloc[0]
# Out:
# 'Ifood me vem com esses stories patrocinados, eu fico alucinada com a comida, vou ver o restaurante é em Recife! Vai tomar no cu Ifood, arrombado do caralho!!!!'

# %%
text = " ".join(review for review in df.tuites.astype(str))

# %%
print ("There are {} words in the combination of all cells in column habitos.".format(len(text)))
# Out:
# There are 27245 words in the combination of all cells in column habitos.

# %%
wordcloud = WordCloud(background_color="white", width=800, height=400).generate(text)
plt.axis("off")
plt.figure( figsize=(40,20))
plt.tight_layout(pad=0)
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()
